# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanketpawar821/LGMVIP/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2             # Importing Necessary Libraries.
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/istockphoto-962855368-612x612.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=491x612 at 0x7F28F6E0D710>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=491x612 at 0x7F28F6E0D790>

# %%
invert_img = 225-gray_img
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=491x612 at 0x7F28F6D4AE10>

# %%
img_smoothen = cv2.GaussianBlur(invert_img, (21, 21), sigmaX = 0, sigmaY = 0)
cv2_imshow(img_smoothen)
# Out:
# <PIL.Image.Image image mode=L size=491x612 at 0x7F28F6D55ED0>

# %%
inverted_blurr = 255-img_smoothen
pencil_sketch = cv2.divide(gray_img, invert_img, inverted_blurr, scale = 256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=491x612 at 0x7F28F6D55ED0>

# %%
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=491x612 at 0x7F28F6D60D10>
# <PIL.Image.Image image mode=L size=491x612 at 0x7F28F6D60D10>
